# %%
pip install pandas numpy
# Out:
# ...
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    --------- ------------------------------ 2.6/11.1 MB 15.3 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.1 MB 17.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.2/11.1 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 15.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ----------- ---------------------------- 3.7/12.4 MB 17.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.1/12.4 MB 17.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.0/12.4 MB 17.7 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 15.9 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
# ...

# %%
import pandas as pd

# %%
data = pd.DataFrame({"Name": ['Mallika', 'Barun', 'Hrid','Gogo', 'john'],
                     "Race": ["Asian", "Asian", "Asian", "hispanic", 'caucasian'],
                     "Age": [34,43,4,11, 19]})

# %%
data.head()
# Out:
#       Name       Race  Age
# 0  Mallika      Asian   34
# 1    Barun      Asian   43
# 2     Hrid      Asian    4
# 3     Gogo   hispanic   11
# 4     john  caucasian   19

# %%
data['Age_2'] = data['Age'].apply(lambda x: x/10)

# %%
data.head()
# Out:
#       Name      Race  Age  Age_2
# 0  Mallika     Asian   34    3.4
# 1    Barun     Asian   43    4.3
# 2     Hrid     Asian    4    0.4
# 3     Gogo  hispanic    4    0.4

# %%
data['Age_label'] = data['Age'].apply(lambda x: 'adult' if x >= 18 else 'minor')

# %%
data.head()
# Out:
#       Name       Race  Age  Age_2 Age_label
# 0  Mallika      Asian   34    3.4     adult
# 1    Barun      Asian   43    4.3     adult
# 2     Hrid      Asian    4    0.4     minor
# 3     Gogo   hispanic   11    1.1     minor
# 4     john  caucasian   19    1.9     adult
